# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
R0=np.logspace(-7.5,-4.0,5)

# %%
R0
# Out:
# array([3.16227766e-08, 2.37137371e-07, 1.77827941e-06, 1.33352143e-05,
#        1.00000000e-04])

# %%
Bubble = np.genfromtxt("results/RP_R1.000e-05_fa2.140e+04_pa1.320e+05.txt", delimiter=" ")

# %%
Bubble
# Out:
# array([[ 0.000000e+00,  0.000000e+00,  1.000000e-07, ...,  1.144000e+05,
#          1.000000e+05,  1.000000e+05],
#        [ 1.000000e+00,  2.804812e-09,  2.804812e-09, ...,  1.144000e+05,
#          9.999998e+04,  9.995022e+04],
#        [ 2.000000e+00,  5.381719e-09,  2.576906e-09, ...,  1.144000e+05,
#          9.999994e+04,  9.990448e+04],
#        ...,
#        [ 4.499000e+03,  5.480503e-05,  1.120285e-07, ...,  6.544404e+02,
#         -3.675613e+03, -1.678394e+04],
#        [ 4.500000e+03,  5.492146e-05,  1.164327e-07, ...,  6.494464e+02,
#         -3.699583e+03, -1.773282e+04],
#        [ 4.501000e+03,  5.500000e-05,  7.854063e-08, ...,  6.459075e+02,
#         -3.716502e+03, -1.835662e+04]])

# %%
Pinf = Bubble[:,-1]

# %%
plt.plot(Bubble[:, 1]*1e6,Pinf)
